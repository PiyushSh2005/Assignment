# %% [markdown]
# numpy and pandas

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Products.csv")

# %%
df
# Out:
#     Product  Price
# 0    Laptop  70000
# 1     Mouse   1500
# 2  Keyboard   2000
# 3   Monitor  20000
# 4   Printer  14000

# %%
avg=df["Price"].mean()
avg
# Out:
# np.float64(21500.0)

# %%
# def fun():
#   for i in range(len(df)):
#     print(df[df["Price"]>avg])

# %%
def fun1():
  for i in range(len(df)):
    if df["Price"][i]>avg:
      print(df["Product"][i],df["Price"][i])

# %%
fun1()
# Out:
# Laptop 70000

# %%
df1=pd.read_csv("Book1.csv")

# %%
df1
# Out:
#         Days  Temp
# 0     Monday    22
# 1    Tuesday    44
# 2  Wednesday    40
# 3   Thursday    45
# 4     Friday    10
# 5   Saturday    25
# 6     Sunday    15

# %%
df['Temp'].min()
# Out:
# 10

# %%
df['Temp'].max()
# Out:
# 45

# %%
df['Temp'].mean()
# Out:
# np.float64(28.714285714285715)

# %%
def cate(Temp):
    if Temp < 20:
        return "Cold"
    elif Temp <= 30:
        return "Moderate"
    else:
        return "Hot"

# %%
for i in range(len(df)):
  print(df["Days"][i], cate(df["Temp"][i]))
# Out:
# Monday Moderate
# Tuesday Hot
# Wednesday Hot
# Thursday Hot
# Friday Cold
# Saturday Moderate
# Sunday Cold
